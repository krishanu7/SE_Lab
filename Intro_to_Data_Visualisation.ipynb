# %% [markdown]
# # Introduction to Data Visualisation
# __Topics to be covered:__
# 1. Data Analytics v/s Data Science
# 2. Python, Pandas & Plotting
# 3. Types of Plots & Charts
# 4. Binge your way through data 🎉
#
# [Best-Selling Textbook on Data Analytics](https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/Index.ipynb#scrollTo=bTr7GMeP-xM3)
#
# [Let's Talk AI Playlist](https://www.youtube.com/watch?v=Lig-F7HkUe0&list=PLxzcBWDhqgYw_Eqjngya69RkstISoxhnR)
#
# [Download Films DataSet](https://drive.google.com/file/d/1BbR0aqH2VWJzmbIocQsKIAOnZ7LyV-2c/view?usp=sharing)

# %% [markdown]
# ### Data Analytics v/s Data Science
# **Data Analytics**
#   - Data Analytics is the sub set
#   - Data Analytics refers to the process of extracting clean information to formulate actionable insights.
#
# **Data Science**
#   - Data Science is the super set
#   - Data science is an interdisciplinary field that uses scientific methods, processes, algorithms and systems to extract knowledge and insights from noisy, structured and unstructured data, and apply knowledge and actionable insights from data across a broad range of application domains.
#
# [HBS on Data Analytics & Data Science](https://drive.google.com/file/d/1Ck97huUcQp3sny2jVn33qt_i-WYFzfCR/view?usp=sharing)

# %% [markdown]
# ### What is Google Colab?

# %% [markdown]
# ### Python
# [Python Crash Course Notebook](https://colab.research.google.com/drive/10TVSEhW4bVSxlw-Gk5CPxQ3i5tvgE_EJ?usp=sharing)
#
# **Variables**

# %%
# Data Types
name = "Pranna"  # String
age = 19  # Integer
am_i_good_human = False  # Boolean - Binary - True or False
height = 180.5 # Float - Any value with decimal

# %% [markdown]
# **Looping & Conditionals**

# %%
if am_i_good_human == True:
  print("Friend")
else:
  print("Enemy")
# Out:
# Enemy

# %%
if age < 18:
  print("Neither adult, cannot drink either")
elif age < 21:
  print("Adult, cannot drink")
else:
  print("Adult and can drink")
# Out:
# Adult, cannot drink

# %%
print("Prannay")
print("Prannay")
print("Prannay")
print("Prannay")
# Out:
# Prannay
# Prannay
# Prannay
# Prannay

# %%
for i in range(10):
  print(i)
  print("Prannay")
# Out:
# 0
# Prannay
# 1
# Prannay
# 2
# Prannay
# 3
# Prannay
# 4
# Prannay
# 5
# Prannay
# 6
# Prannay
# 7
# Prannay
# 8
# Prannay
# 9
# Prannay

# %% [markdown]
# **Python Lists**

# %%
# human = ['Prannay', 19, False, 180.5]
stock_prices = [100, 102, 97, 98]
print(stock_prices)
# Out:
# [100, 102, 97, 98]

# %% [markdown]
# ### Pandas
#
# [Link to Pandas Documentation](https://pandas.pydata.org/docs/)

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# **Importing CSV or Excel Files**

# %%
df = pd.read_csv("/content/Films.csv")
df.head()
# Out:
#    Rank Release_Date  ... USD_Worldwide_Gross  USD_Domestic_Gross
# 0  5293   1915-08-02  ...            11000000            10000000
# 1  5140   1916-05-09  ...                   0                   0
# 2  5230   1916-12-24  ...             8000000             8000000
# 3  5299   1920-09-17  ...             3000000             3000000
# 4  5222   1925-01-01  ...            22000000            11000000
#
# [5 rows x 6 columns]

# %%
df
# Out:
#       Rank Release_Date  ... USD_Worldwide_Gross  USD_Domestic_Gross
# 0     5293   1915-08-02  ...            11000000            10000000
# 1     5140   1916-05-09  ...                   0                   0
# 2     5230   1916-12-24  ...             8000000             8000000
# 3     5299   1920-09-17  ...             3000000             3000000
# 4     5222   1925-01-01  ...            22000000            11000000
# ...    ...          ...  ...                 ...                 ...
# 5386  2950   2018-10-08  ...                   0                   0
# 5387   126   2018-12-18  ...                   0                   0
# 5388    96   2020-12-31  ...                   0                   0
# 5389  1119   2020-12-31  ...                   0                   0
# 5390  2517   2020-12-31  ...                   0                   0
#
# [5391 rows x 6 columns]

# %%
df.tail()
# Out:
#       Rank Release_Date  ... USD_Worldwide_Gross  USD_Domestic_Gross
# 5386  2950   2018-10-08  ...                   0                   0
# 5387   126   2018-12-18  ...                   0                   0
# 5388    96   2020-12-31  ...                   0                   0
# 5389  1119   2020-12-31  ...                   0                   0
# 5390  2517   2020-12-31  ...                   0                   0
#
# [5 rows x 6 columns]

# %%
df.shape
# Out:
# (5391, 6)

# %%
df["USD_Production_Budget"][df["Movie_Title"] == "Meg"]
# Out:
# 5386    15000000
# Name: USD_Production_Budget, dtype: int64

# %%
df["USD_Production_Budget"].loc[5386]
# Out:
# 15000000

# %% [markdown]
# **Viewing Basic Stats**

# %%
df.describe()
# Out:
#               Rank  ...  USD_Domestic_Gross
# count  5391.000000  ...        5.391000e+03
# mean   2696.000000  ...        4.123552e+07
# std    1556.391981  ...        6.602935e+07
# min       1.000000  ...        0.000000e+00
# 25%    1348.500000  ...        1.330902e+06
# 50%    2696.000000  ...        1.719220e+07
# 75%    4043.500000  ...        5.234369e+07
# max    5391.000000  ...        9.366622e+08
#
# [8 rows x 4 columns]

# %% [markdown]
# ### Types of Plots
# 1. **Line Chart**: Used when you want to show trends or make comparisons
# 2. **Bar Chart**: Used to display data grouped intro discrete non-numeric category
# 3. **Histogram**: Used to represent continous data and shape of data distribution
# 4. **Pie Chart**: Used to represent composition and show percentages
# 5. **Scatter Plot**: Used to find the relationship between 2 variables. Are also great for identifying outlier points and possible gaps in the data.
# 6. **Stacked Area Chart**: This chart is most often seen when combined with the concept of stacking, to show how both how a total has changed over time, but also how its components’ contributions have changed.
#
# [Click to Read More about Plots](https://www.intellspot.com/types-graphs-charts/)

# %% [markdown]
# ### Plotting

# %% [markdown]
# **Plotly - Your Saviour**
#
# [Link to Plotly Documentation](https://plotly.com/python/)

# %%
px.scatter(x=df["USD_Production_Budget"], y=df["USD_Worldwide_Gross"], labels={'x': 'USD Production Budget', 'y': 'USD Worldwide Gross'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(y=df["USD_Production_Budget"], x=df["Release_Date"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(x=df["Rank"], y=df["USD_Worldwide_Gross"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(x=df["Rank"], y=df["USD_Worldwide_Gross"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(x=df["Rank"], y=df["USD_Production_Budget"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(y=df["Rank"], x=df["Release_Date"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# You can go through another plotting library called matplotlib too. Although Plotly is much easier to use.
#
# [Link to Matplotlib Documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html)

# %% [markdown]
# # NO CODE!
# - [Data Wrapper](https://www.datawrapper.de)
# - [Plotly](https://plotly.com) - Paid
# - [Knime](https://www.knime.com) - Open Source
